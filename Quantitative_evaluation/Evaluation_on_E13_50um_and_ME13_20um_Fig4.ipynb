# %% [markdown]
# # Quantitative evaluation on E13_50um data and ME13_20um data
#
# This notebook aims to reproduce the quantitative evaluation results on these two datasets, using unsupervised metrics including jaccard similarity and Moran’s I score.

# %%
# E13_50um Quantitative Evaluation

import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (6,4)
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 15
sns.set(style="white", font_scale=1.0)

RESULT_DIR = "../result/Fig4/"
CSV_PATH   = os.path.join(RESULT_DIR, "metrics_E13_50um.csv")
FIG_DIR    = "../Figure/"
os.makedirs(FIG_DIR, exist_ok=True)

df = pd.read_csv(CSV_PATH)
df.head()

df_j = df[df["MetricGroup"]=="jaccard"].copy()

methods_order = ['MISO','GSMO','MISO+image','GSMO+image']

modalities_order = ['RNA','ATAC','H3K27me3','H3K4me3','image']
modality_colors = {
    'RNA': "#72aacf",      
    'ATAC': "#cae8f2",     
    'H3K27me3': "#fefbba", 
    'H3K4me3': "#fdb96b",  
    'image': "#ec5d3b"     
}

mat = df_j.pivot_table(index="Method", columns="Modality", values="Value", aggfunc="first").fillna(0.0)

mat = mat.reindex(index=methods_order)
modalities = [m for m in modalities_order if m in mat.columns]
mat = mat.loc[:, modalities]

fig, ax = plt.subplots(figsize=(5,5.5))
bottom = np.zeros(len(mat), dtype=float)
xlabels = mat.index.tolist()
x = np.arange(len(xlabels))

for modality in modalities:
    vals = mat[modality].values.astype(float)
    ax.bar(xlabels, vals, bottom=bottom, label=f"{modality}-joint",
           color=modality_colors[modality], width=0.5)
    bottom = bottom + vals

ax.set_ylabel("Jaccard similarity")
ax.set_ylim(0, float(mat.sum(axis=1).max()) * 1.5)
plt.xticks(rotation=45, ha='right')
ax.legend(title="", loc='upper left')
plt.tight_layout()

out_path = os.path.join(FIG_DIR, "E13_50um_jaccard_stacked_bar.png")
plt.savefig(out_path, dpi=300, bbox_inches='tight')
plt.show()
print(f"[OK] saved: {out_path}")
# Out:
# [OK] saved: ../Figure/E13_50um_jaccard_stacked_bar.png

# %%
df_m = df[df["MetricGroup"]=="moran"].copy()
df_m = df_m.rename(columns={"Value":"Score"})


def make_label(method):
    base = method.replace("+image","")
    group = "With Image" if "+image" in method else "No Image"
    return f"{base} ({group})", group

labels, groups = [], []
for m in df_m["Method"]:
    lab, grp = make_label(m)
    labels.append(lab); groups.append(grp)
df_m["Label"] = labels
df_m["Group"] = groups


color_map = {
    'MISO (No Image)'  : "#9ce7d2ff",
    'MISO (With Image)': "#05bd89",
    'GSMO (No Image)'  : "#f8ca84",
    'GSMO (With Image)': "#e9a135",
}

x_positions = {
    'MISO (No Image)'  : 1.3,
    'GSMO (No Image)'  : 1.9,
    'MISO (With Image)': 2.9,
    'GSMO (With Image)': 3.5
}

plt.figure(figsize=(6,3))
for label in x_positions.keys():
    vals = df_m[df_m["Label"] == label]["Score"].values
    if len(vals)==0:
        continue
    plt.boxplot(vals, positions=[x_positions[label]], widths=0.5, patch_artist=True,
                boxprops=dict(facecolor=color_map[label], linewidth=1.5),
                medianprops=dict(color='black'),
                flierprops=dict(marker='D', markerfacecolor='black', markersize=5))

plt.xticks([1.6, 3.2], ['No Image', 'With Image'], fontsize=11)
plt.ylabel("Moran's I score")
plt.title("Cluster-wise Moran's I Comparison", fontsize=13)

from matplotlib.patches import Patch
legend_patches = [Patch(facecolor=color_map[k], label=k) for k in x_positions.keys()]
plt.legend(handles=legend_patches, title='Method', loc='upper left', bbox_to_anchor=(1.02, 1), borderaxespad=0)

sns.despine()
plt.tight_layout()

out_path2 = os.path.join(FIG_DIR, "E13_50um_moran_fine_control_plot.png")
plt.savefig(out_path2, dpi=400, bbox_inches='tight')
plt.show()
print(f"[OK] saved: {out_path2}")
# Out:
# [OK] saved: ../Figure/E13_50um_moran_fine_control_plot.png

# %%
# ME13_20um Quantitative Evaluation

import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (6,4)
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 15
sns.set(style="white", font_scale=1.0)

RESULT_DIR = "../result/Fig4/"
CSV_PATH   = os.path.join(RESULT_DIR, "metrics_E13_20um.csv")
FIG_DIR    = "../Figure/"
os.makedirs(FIG_DIR, exist_ok=True)

df = pd.read_csv(CSV_PATH)
df.head()

df_j = df[df["MetricGroup"]=="jaccard"].copy()

methods_order = ['MISO','GSMO','MISO+image','GSMO+image']

modalities_order = ['RNA','protein','H3K27me3','H3K4me3','image']
modality_colors = {
    'RNA': "#8ec783",      # 蓝
    'protein': "#c4e9bc",     # 浅蓝
    'H3K27me3': "#fefbba", # 浅黄
    'H3K4me3': "#fdb96b",  # 橙
    'image': "#ec5d3b"     # 红橙
}


mat = df_j.pivot_table(index="Method", columns="Modality", values="Value", aggfunc="first").fillna(0.0)

mat = mat.reindex(index=methods_order)
modalities = [m for m in modalities_order if m in mat.columns]
mat = mat.loc[:, modalities]

fig, ax = plt.subplots(figsize=(5,5.5))
bottom = np.zeros(len(mat), dtype=float)
xlabels = mat.index.tolist()
x = np.arange(len(xlabels))

for modality in modalities:
    vals = mat[modality].values.astype(float)
    ax.bar(xlabels, vals, bottom=bottom, label=f"{modality}-joint",
           color=modality_colors[modality], width=0.5)
    bottom = bottom + vals

ax.set_ylabel("Jaccard similarity")
ax.set_ylim(0, float(mat.sum(axis=1).max()) * 1.5)
plt.xticks(rotation=45, ha='right')
ax.legend(title="", loc='upper left')
plt.tight_layout()

out_path = os.path.join(FIG_DIR, "E13_20um_jaccard_stacked_bar.png")
plt.savefig(out_path, dpi=300, bbox_inches='tight')
plt.show()
print(f"[OK] saved: {out_path}")
# Out:
# [OK] saved: ../Figure/E13_20um_jaccard_stacked_bar.png

# %%
df_m = df[df["MetricGroup"]=="moran"].copy()
df_m = df_m.rename(columns={"Value":"Score"})

def make_label(method):
    base = method.replace("+image","")
    group = "With Image" if "+image" in method else "No Image"
    return f"{base} ({group})", group

labels, groups = [], []
for m in df_m["Method"]:
    lab, grp = make_label(m)
    labels.append(lab); groups.append(grp)
df_m["Label"] = labels
df_m["Group"] = groups

color_map = {
    'MISO (No Image)'  : "#9ce7d2ff",
    'MISO (With Image)': "#05bd89",
    'GSMO (No Image)'  : "#f8ca84",
    'GSMO (With Image)': "#e9a135",
}

x_positions = {
    'MISO (No Image)'  : 1.3,
    'GSMO (No Image)'  : 1.9,
    'MISO (With Image)': 2.9,
    'GSMO (With Image)': 3.5
}

plt.figure(figsize=(6,3))
for label in x_positions.keys():
    vals = df_m[df_m["Label"] == label]["Score"].values
    if len(vals)==0:
        continue
    plt.boxplot(vals, positions=[x_positions[label]], widths=0.5, patch_artist=True,
                boxprops=dict(facecolor=color_map[label], linewidth=1.5),
                medianprops=dict(color='black'),
                flierprops=dict(marker='D', markerfacecolor='black', markersize=5))

plt.xticks([1.6, 3.2], ['No Image', 'With Image'], fontsize=11)
plt.ylabel("Moran's I score")
plt.title("Cluster-wise Moran's I Comparison", fontsize=13)

from matplotlib.patches import Patch
legend_patches = [Patch(facecolor=color_map[k], label=k) for k in x_positions.keys()]
plt.legend(handles=legend_patches, title='Method', loc='upper left', bbox_to_anchor=(1.02, 1), borderaxespad=0)

sns.despine()
plt.tight_layout()

out_path2 = os.path.join(FIG_DIR, "E13_20um_moran_fine_control_plot.png")
plt.savefig(out_path2, dpi=400, bbox_inches='tight')
plt.show()
print(f"[OK] saved: {out_path2}")
# Out:
# [OK] saved: ../Figure/E13_20um_moran_fine_control_plot.png

# %%
# ME13_20um_3m Quantitative Evaluation

import os, numpy as np, pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['figure.figsize'] = (6,4)
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 15
sns.set(style="white", font_scale=1.0)

RESULT_DIR = "../result/Fig4/"
CSV_PATH   = os.path.join(RESULT_DIR, "metrics_E13_20um_3m.csv")
FIG_DIR    = "../Figure/"
os.makedirs(FIG_DIR, exist_ok=True)

df = pd.read_csv(CSV_PATH)
df.head()
df_j = df[df["MetricGroup"]=="jaccard"].copy()

methods_order = ['MISO','GSMO','MISO+image','GSMO+image']

modalities_order = ['RNA','protein','H3K27me3','H3K4me3','image']
modality_colors = {
    'RNA': "#8ec783",      
    'protein': "#c4e9bc",     
    'H3K27me3': "#fefbba", 
    'H3K4me3': "#fdb96b",  
    'image': "#ec5d3b"     
}

# pivot 成 methods x modalities
mat = df_j.pivot_table(index="Method", columns="Modality", values="Value", aggfunc="first").fillna(0.0)

mat = mat.reindex(index=methods_order)
modalities = [m for m in modalities_order if m in mat.columns]
mat = mat.loc[:, modalities]

fig, ax = plt.subplots(figsize=(5,5.5))
bottom = np.zeros(len(mat), dtype=float)
xlabels = mat.index.tolist()
x = np.arange(len(xlabels))

for modality in modalities:
    vals = mat[modality].values.astype(float)
    ax.bar(xlabels, vals, bottom=bottom, label=f"{modality}-joint",
           color=modality_colors[modality], width=0.5)
    bottom = bottom + vals

ax.set_ylabel("Jaccard similarity")
ax.set_ylim(0, float(mat.sum(axis=1).max()) * 1.5)
plt.xticks(rotation=45, ha='right')
ax.legend(title="", loc='upper left')
plt.tight_layout()

out_path = os.path.join(FIG_DIR, "E13_20um_3m_jaccard_stacked_bar.png")
plt.savefig(out_path, dpi=300, bbox_inches='tight')
plt.show()
print(f"[OK] saved: {out_path}")
# Out:
# [OK] saved: ../Figure/E13_20um_3m_jaccard_stacked_bar.png

# %%
df_m = df[df["MetricGroup"]=="moran"].copy()
df_m = df_m.rename(columns={"Value":"Score"})

def make_label(method):
    base = method.replace("+image","")
    group = "With Image" if "+image" in method else "No Image"
    return f"{base} ({group})", group

labels, groups = [], []
for m in df_m["Method"]:
    lab, grp = make_label(m)
    labels.append(lab); groups.append(grp)
df_m["Label"] = labels
df_m["Group"] = groups

color_map = {
    'MISO (No Image)'  : "#9ce7d2ff",
    'MISO (With Image)': "#05bd89",
    'GSMO (No Image)'  : "#f8ca84",
    'GSMO (With Image)': "#e9a135",
}

x_positions = {
    'MISO (No Image)'  : 1.3,
    'GSMO (No Image)'  : 1.9,
    'MISO (With Image)': 2.9,
    'GSMO (With Image)': 3.5
}

plt.figure(figsize=(6,3))
for label in x_positions.keys():
    vals = df_m[df_m["Label"] == label]["Score"].values
    if len(vals)==0:
        continue
    plt.boxplot(vals, positions=[x_positions[label]], widths=0.5, patch_artist=True,
                boxprops=dict(facecolor=color_map[label], linewidth=1.5),
                medianprops=dict(color='black'),
                flierprops=dict(marker='D', markerfacecolor='black', markersize=5))

plt.xticks([1.6, 3.2], ['No Image', 'With Image'], fontsize=11)
plt.ylabel("Moran's I score")
plt.title("Cluster-wise Moran's I Comparison", fontsize=13)

from matplotlib.patches import Patch
legend_patches = [Patch(facecolor=color_map[k], label=k) for k in x_positions.keys()]
plt.legend(handles=legend_patches, title='Method', loc='upper left', bbox_to_anchor=(1.02, 1), borderaxespad=0)

sns.despine()
plt.tight_layout()

out_path2 = os.path.join(FIG_DIR, "E13_20um_3m_moran_fine_control_plot.png")
plt.savefig(out_path2, dpi=400, bbox_inches='tight')
plt.show()
print(f"[OK] saved: {out_path2}")
# Out:
# [OK] saved: ../Figure/E13_20um_3m_moran_fine_control_plot.png
